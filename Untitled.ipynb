# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url = 'data (5).csv'
df = pd.read_csv(url, index_col = 0)
df.head()
# Out:
#             Lat       Lng      Area  Children  Age    Income   Marital  \
# State
# AL     34.34960 -86.72508  Suburban       1.0   53  86575.93  Divorced
# FL     30.84513 -85.22907     Urban       3.0   51  46805.99   Married
# SD     43.54321 -96.63772  Suburban       3.0   53  14370.14   Widowed
# MN     43.89744 -93.51479  Suburban       0.0   78  39741.49   Married
# VA     37.59894 -76.88958     Rural       1.0   22   1209.56   Widowed
#
#        Gender  ReAdmis  VitD_levels  ...  Hyperlipidemia  BackPain  Anxiety  \
# State                                ...
# AL       Male        0    19.141466  ...             0.0       1.0      1.0
# FL     Female        0    18.940352  ...             0.0       0.0      0.0
# SD     Female        0    18.057507  ...             0.0       0.0      0.0
# MN       Male        0    16.576858  ...             0.0       0.0      0.0
# VA     Female        0    17.439069  ...             1.0       0.0      0.0
#
#        Allergic_rhinitis Reflux_esophagitis  Asthma     Services Initial_days  \
# State
# AL                   1.0                  0       1   Blood Work    10.585770
# FL                   0.0                  1       0  Intravenous    15.129562
# SD                   0.0                  0       0   Blood Work     4.772177
# MN                   0.0                  1       1   Blood Work     1.714879
# VA                   1.0                  0       0      CT Scan     1.254807
#
#        TotalCharge  Additional_charges
# State
# AL     3726.702860        17939.403420
# FL     4193.190458        17612.998120
# SD     2434.234222        17505.192460
# MN     2127.830423        12993.437350
# VA     2113.073274         3716.525786
#
# [5 rows x 31 columns]

# %% [markdown]
# The features to analyze:
# - VitD_levels
# - Doc_visits
# - TotalCharge

# %% [markdown]
# Plot a histogram with a kde (kernel density estimate)
# - Add a line for the mean (red)
# - Add a line for the median (green)

# %%
col = 'VitD_levels'
feature = df[col]
mean = feature.mean()
median = feature.median()
fig,ax = plt.subplots(figsize=(10,6))
sns.histplot(feature ,ax=ax,stat='probability',kde=True)
ax.axvline(mean, color = 'red',label=f'Mean = {mean:,.2f}')
ax.axvline(median, ls='--', color = 'green', label = f'Median = {median:,.2f}')
ax.set_title(f'{col}')
ax.legend();

# %% [markdown]
# - Add a line for for +1 std from the mean (black)
# - Add a line for the - 1 std from the mean (black)

# %%
col = 'VitD_levels'
feature = df[col]
mean = feature.mean()
median = feature.median()
std = feature.std()
plus_one_std = mean + std
minus_one_std = mean - std
fig,ax = plt.subplots(figsize=(10,6))
sns.histplot(feature ,ax=ax,stat='probability',kde=True)
ax.axvline(plus_one_std, color = 'black',label=f'+1 std = {plus_one_std:,.2f}')
ax.axvline(minus_one_std, color = 'black', label = f'-1 std = {minus_one_std:,.2f}')
ax.set_title(f'{col}')
ax.legend();

# %% [markdown]
# Highlight the range between +1 and =1 std (yellow)

# %%
col = 'VitD_levels'
feature = df[col]
mean = feature.mean()
median = feature.median()
std = feature.std()
plus_one_std = mean + std
minus_one_std = mean - std
fig,ax = plt.subplots(figsize=(10,6))
sns.histplot(feature ,ax=ax,stat='probability',kde=True)
ax.axvline(plus_one_std, color = 'black',label=f'+1 std = {plus_one_std:,.2f}')
ax.axvline(minus_one_std, color = 'black', label = f'-1 std = {minus_one_std:,.2f}')
ax.axvspan(plus_one_std, minus_one_std, color = 'yellow', zorder = 0)
ax.set_title(f'{col}')
ax.legend();

# %% [markdown]
# Answer the following questions:
# Is it Discrete or Continuous?
# Does it have a skew? If so, which direction (+/-)
# What type of kurtosis does it display? (Mesokurtic, Leptokurtic, Platykurtic)

# %%
from scipy import stats
kurt = stats.kurtosis(df['VitD_levels'], fisher = False)
kurt
# Out:
# 3.013147515833447

# %% [markdown]
# - ### This is continuous since it has no separate space between bars
# - ### It has no skew since the mean and the median are the same so it is normal
# - ### since kurt values are 3.013 , it's normal distribution called Mesokurtic.

# %% [markdown]
# continuing for the second column Doc_visits

# %%
col = 'Doc_visits'
feature = df[col]
mean = feature.mean()
median = feature.median()
fig,ax = plt.subplots(figsize=(10,6))
sns.histplot(feature ,ax=ax,stat='probability',kde=True)
ax.axvline(mean, color = 'red',label=f'Mean = {mean:,.2f}')
ax.axvline(median, ls='--', color = 'green', label = f'Median = {median:,.2f}')
ax.set_title(f'{col}')
ax.legend();

# %% [markdown]
# - Add a line for for +1 std from the mean (black)
# - Add a line for the - 1 std from the mean (black)

# %%
col = 'Doc_visits'
feature = df[col]
mean = feature.mean()
median = feature.median()
std = feature.std()
plus_one_std = mean + std
minus_one_std = mean - std
fig,ax = plt.subplots(figsize=(10,6))
sns.histplot(feature ,ax=ax,stat='probability',kde=True)
ax.axvline(plus_one_std, color = 'black',label=f'+1 std = {plus_one_std:,.2f}')
ax.axvline(minus_one_std, color = 'black', label = f'-1 std = {minus_one_std:,.2f}')
ax.set_title(f'{col}')
ax.legend();

# %% [markdown]
# Highlight the range between +1 and =1 std (yellow)

# %%
col = 'Doc_visits'
feature = df[col]
mean = feature.mean()
median = feature.median()
std = feature.std()
plus_one_std = mean + std
minus_one_std = mean - std
fig,ax = plt.subplots(figsize=(10,6))
sns.histplot(feature ,ax=ax,stat='probability',kde=True)
ax.axvline(plus_one_std, color = 'black',label=f'+1 std = {plus_one_std:,.2f}')
ax.axvline(minus_one_std, color = 'black', label = f'-1 std = {minus_one_std:,.2f}')
ax.axvspan(plus_one_std, minus_one_std, color = 'yellow', zorder = 0)
ax.set_title(f'{col}')
ax.legend();

# %%
from scipy import stats
kurt = stats.kurtosis(df['Doc_visits'], fisher = False)
kurt
# Out:
# 2.9919958083381206

# %% [markdown]
# - ### This is discrete since it has separate space between bars
# - ### It has no skew since the mean and the median lie at the same line so it is normal
# - ### since kurt values are < 3 , it's Platykurtic  and called nagative curtosis, values cluster in the tails of the distribution

# %% [markdown]
# continuing for the third column TotalCharge

# %%
col = 'TotalCharge'
feature = df[col]
mean = feature.mean()
median = feature.median()
fig,ax = plt.subplots(figsize=(10,6))
sns.histplot(feature ,ax=ax,stat='probability',kde=True)
ax.axvline(mean, color = 'red',label=f'Mean = {mean:,.2f}')
ax.axvline(median, ls='--', color = 'green', label = f'Median = {median:,.2f}')
ax.set_title(f'{col}')
ax.legend();

# %% [markdown]
# Add a line for for +1 std from the mean (black)
# Add a line for the - 1 std from the mean (black)

# %%
col = 'TotalCharge'
feature = df[col]
mean = feature.mean()
median = feature.median()
std = feature.std()
plus_one_std = mean + std
minus_one_std = mean - std
fig,ax = plt.subplots(figsize=(10,6))
sns.histplot(feature ,ax=ax,stat='probability',kde=True)
ax.axvline(plus_one_std, color = 'black',label=f'+1 std = {plus_one_std:,.2f}')
ax.axvline(minus_one_std, color = 'black', label = f'-1 std = {minus_one_std:,.2f}')
ax.set_title(f'{col}')
ax.legend();

# %% [markdown]
# Highlight the range between +1 and =1 std (yellow)

# %%
col = 'TotalCharge'
feature = df[col]
mean = feature.mean()
median = feature.median()
std = feature.std()
plus_one_std = mean + std
minus_one_std = mean - std
fig,ax = plt.subplots(figsize=(10,6))
sns.histplot(feature ,ax=ax,stat='probability',kde=True)
ax.axvline(plus_one_std, color = 'black',label=f'+1 std = {plus_one_std:,.2f}')
ax.axvline(minus_one_std, color = 'black', label = f'-1 std = {minus_one_std:,.2f}')
ax.axvspan(plus_one_std, minus_one_std, color = 'yellow', zorder = 0)
ax.set_title(f'{col}')
ax.legend();

# %% [markdown]
# Answer the following questions:
# Is it Discrete or Continuous?
# Does it have a skew? If so, which direction (+/-)
# What type of kurtosis does it display? (Mesokurtic, Leptokurtic, Platykurtic)

# %%
from scipy import stats
kurt = stats.kurtosis(df['TotalCharge'], fisher = False)
kurt
# Out:
# 3.2650077463439384

# %% [markdown]
# - ### This is continous since it has no separate space between bars
# - ### It has a skew since the mean and the median don't lie at the same line and since it is moving in the postive direction meaning more values are at the left, it is called postively skewed.
# - ### since kurt values are < 3 , it's Platykurtic  and called nagative curtosis, values cluster in the tails of the distribution
